# %%
import pandas as pd

# %%
#df = pd.read_csv("data_sets/health_data/annual-mortality-rate-from-seasonal-influenza-ages-65.csv")
df = pd.read_csv("data_sets/air_quality/Air_Polution.csv")

# %%
df.head()
# Out:
#   Country Name     City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0  Afghanistan    Kabul  2019         119.77           NaN          NaN
# 1      Albania   Durres  2015            NaN         17.65        26.63
# 2      Albania   Durres  2016          14.32         24.56        24.78
# 3      Albania  Elbasan  2015            NaN           NaN        23.96
# 4      Albania  Elbasan  2016            NaN           NaN        26.26
#
#    PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                        18.0                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    NO2 temporal coverage (%)  Updated Year
# 0                        NaN          2022
# 1                  83.961187          2022
# 2                  87.932605          2022
# 3                  97.853881          2022
# 4                  96.049636          2022

# %%
df.shape
# Out:
# (32191, 10)

# %%
df.tail()
# Out:
#       Country Name       City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 32186     Viet Nam  Nha Trang  2013            NaN          30.0          NaN
# 32187     Viet Nam  Nha Trang  2014            NaN          12.0          NaN
# 32188     Viet Nam  Nha Trang  2015            NaN          14.0          NaN
# 32189     Viet Nam   Viet Tri  2013            NaN          27.0          NaN
# 32190     Viet Nam   Viet Tri  2014            NaN          22.0          NaN
#
#        PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 32186                         NaN                         NaN
# 32187                         NaN                         NaN
# 32188                         NaN                         NaN
# 32189                         NaN                         NaN
# 32190                         NaN                         NaN
#
#        NO2 temporal coverage (%)  Updated Year
# 32186                        NaN          2018
# 32187                        NaN          2018
# 32188                        NaN          2018
# 32189                        NaN          2018
# 32190                        NaN          2018

# %%
import os
import pandas as pd


CURR_DIR_PATH = os.path.dirname(os.path.realpath(__file__))
co2_df = pd.read_json(CURR_DIR_PATH+'\\data_sets\\air_quality\\owid-co2-data.json')

who_pm25df = pd.read_csv(CURR_DIR_PATH+'\\data_sets\\air_quality\\WHO_world_pm25_pollution.csv')

# Health dataframes
death_rates_1990_2019df = pd.read_csv(CURR_DIR_PATH+'\\data_sets\\health\\death-rates-from-air-pollution.csv')
death_factor_1990_2019df = pd.read_csv(CURR_DIR_PATH+'\\data_sets\\health\\number-of-deaths-by-risk-factor.csv')
disease_factor_1990_2019df = pd.read_csv(CURR_DIR_PATH+'\\data_sets\\health\\disease-burden-by-risk-factor.csv')

# Clean-up
who_columns_delete = list(range(0,7)) + list(range(8,9)) + list(range(10,23))+ list(range(24,29))+ list(range(30,34))
who_pm25df.drop(who_pm25df.columns[who_columns_delete], axis=1, inplace=True)

death_factor_columns_delete = list(range(3,14)) + list(range(15,18))+ list(range(19,27))+ list(range(28,31))
death_factor_1990_2019df.drop(death_factor_1990_2019df.columns[death_factor_columns_delete], axis=1, inplace=True)

disease_factor_columns_delete = list(range(3,5)) + list(range(6,18))+ list(range(19,24))
disease_factor_1990_2019df.drop(disease_factor_1990_2019df.columns[disease_factor_columns_delete], axis=1, inplace=True)

merged_df = death_rates_1990_2019df.merge(death_factor_1990_2019df, on=['Entity', 'Code', 'Year'], how='inner')
merged_df = merged_df.merge(disease_factor_1990_2019df, on=['Entity', 'Code', 'Year'], how='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\robba\OneDrive\Skrivbord\Programmering\Brights\AAA_Final_project\final_project\test.ipynb Cell 6 line <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/robba/OneDrive/Skrivbord/Programmering/Brights/AAA_Final_project/final_project/test.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import os
#       <a href='vscode-notebook-cell:/c%3A/Users/robba/OneDrive/Skrivbord/Programmering/Brights/AAA_Final_project/final_project/test.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/robba/OneDrive/Skrivbord/Programmering/Brights/AAA_Final_project/final_project/test.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> CURR_DIR_PATH = os.path.dirname(os.path.realpath(__file__))
#       <a href='vscode-notebook-cell:/c%3A/Users/robba/OneDrive/Skrivbord/Programmering/Brights/AAA_Final_project/final_project/test.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> co2_df = pd.read_json(CURR_DIR_PATH+'\\data_sets\\air_quality\\owid-co2-data.json')
#       <a href='vscode-notebook-cell:/c%3A/Users/robba/OneDrive/Skrivbord/Programmering/Brights/AAA_Final_project/final_project/test.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> who_pm25df = pd.read_csv(CURR_DIR_PATH+'\\data_sets\\air_quality\\WHO_world_pm25_pollution.csv')
#
# NameError: name '__file__' is not defined

# %%
import os

import pandas as pd 

 

CURR_DIR_PATH = %pwd 

 

death_rates_1990_2019df = pd.read_csv(os.path.join(CURR_DIR_PATH, 'data_sets', 'health', 'death-rates-from-air-pollution.csv')) death_factor_1990_2019df = pd.read_csv(os.path.join(CURR_DIR_PATH, 'data_sets', 'health', 'number-of-deaths-by-risk-factor.csv')) disease_factor_1990_2019df = pd.read_csv(os.path.join(CURR_DIR_PATH, 'data_sets', 'health', 'disease-burden-by-risk-factor.csv'))
# Out:
#   Input In [2]
#     death_rates_1990_2019df = pd.read_csv(os.path.join(CURR_DIR_PATH, 'data_sets', 'health', 'death-rates-from-air-pollution.csv')) death_factor_1990_2019df = pd.read_csv(os.path.join(CURR_DIR_PATH, 'data_sets', 'health', 'number-of-deaths-by-risk-factor.csv')) disease_factor_1990_2019df = pd.read_csv(os.path.join(CURR_DIR_PATH, 'data_sets', 'health', 'disease-burden-by-risk-factor.csv'))
#                                                                                                                                     ^
# SyntaxError: invalid syntax
